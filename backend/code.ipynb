# %%
# importing required algorithms
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('dataset\diabetes.csv')
data
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
data.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
data.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
#checking the null values in dataset
data.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
data.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
#separating the target column
x=data.iloc[:,:-1]
y=data.iloc[:,-1]

# %%
x
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age
# 0                       0.627   50
# 1                       0.351   31
# ...

# %%
y
# Out:
# 0      1
# 1      0
# 2      1
# 3      0
# 4      1
#       ..
# 763    0
# 764    0
# 765    0
# 766    1
# 767    0
# Name: Outcome, Length: 768, dtype: int64

# %%
#split the data into train and test as x,y
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3)

# %%
x_train
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 701            6      125             78             31        0  27.6
# 715            7      187             50             33      392  33.9
# 633            1      128             82             17      183  27.5
# 513            2       91             62              0        0  27.3
# 498            7      195             70             33      145  25.1
# ..           ...      ...            ...            ...      ...   ...
# 582           12      121             78             17        0  26.5
# 644            3      103             72             30      152  27.6
# 309            2      124             68             28      205  32.9
# 325            1      157             72             21      168  25.6
# 382            1      109             60              8      182  25.4
#
#      DiabetesPedigreeFunction  Age
# 701                     0.565   49
# 715                     0.826   34
# ...

# %%
x_test
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 456            1      135             54              0        0  26.7
# 181            0      119             64             18       92  34.9
# 98             6       93             50             30       64  28.7
# 501            3       84             72             32        0  37.2
# 7             10      115              0              0        0  35.3
# ..           ...      ...            ...            ...      ...   ...
# 739            1      102             74              0        0  39.5
# 65             5       99             74             27        0  29.0
# 262            4       95             70             32        0  32.1
# 90             1       80             55              0        0  19.1
# 452            0       91             68             32      210  39.9
#
#      DiabetesPedigreeFunction  Age
# 456                     0.687   62
# 181                     0.725   23
# ...

# %%
y_train
# Out:
# 701    1
# 715    1
# 633    0
# 513    0
# 498    1
#       ..
# 582    0
# 644    0
# 309    1
# 325    0
# 382    0
# Name: Outcome, Length: 537, dtype: int64

# %%
y_test
# Out:
# 456    0
# 181    0
# 98     0
# 501    0
# 7      0
#       ..
# 739    1
# 65     0
# 262    0
# 90     0
# 452    0
# Name: Outcome, Length: 231, dtype: int64

# %%
# 2 appling machine learning decision tree algorithm
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
dtc = DecisionTreeClassifier()
dtc.fit(x_train, y_train)
y_pred = dtc.predict(x_test)
acc1 = accuracy_score(y_pred, y_test)
acc1 = acc1*100
acc1
# Out:
# 65.80086580086581

# %%
# save the model to disk
import pickle
filename = 'DecisionTreeClassifier.sav'
pickle.dump(dtc, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# 3 appling machine learning random forest algorithm 
from sklearn.ensemble import RandomForestClassifier
forest = RandomForestClassifier()
forest.fit(x_train, y_train)
y_pred = forest.predict(x_test)
acc2 = accuracy_score(y_test, y_pred)
acc2 = acc2*100
acc2
# Out:
# 78.78787878787878

# %%
# save the model to disk
import pickle
filename = 'RandomForestClassifier.sav'
pickle.dump(forest, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
# 8 appling machine learning logistic regression algorithm
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression()
lr.fit(x_train,y_train)
y_pred=lr.predict(x_test)
acc3=accuracy_score(y_pred,y_test)
acc3=acc3*100
acc3
# Out:
# C:\Users\ymts0611\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# 79.65367965367966

# %%
# save the model to disk
import pickle
filename = 'LogisticRegression.sav'
pickle.dump(lr, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
#applying ann algorithm
from sklearn.metrics import accuracy_score
from keras.models import Sequential 
from keras.layers import Dense,Activation,Dropout 
from tensorflow.keras.layers import BatchNormalization
from keras.utils import np_utils

# %%
model=Sequential()
model.add(Dense(1000,input_dim=8,activation='relu'))
model.add(Dense(500,activation='relu'))
model.add(Dense(300,activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(1,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense (Dense)               (None, 1000)              9000
#
#  dense_1 (Dense)             (None, 500)               500500
#
#  dense_2 (Dense)             (None, 300)               150300
#
#  dropout (Dropout)           (None, 300)               0
#
#  dense_3 (Dense)             (None, 1)                 301
#
# ...
# Total params: 660,101
# Trainable params: 660,101
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(x_train,y_train,validation_data=(x_test,y_test),batch_size=20,epochs=20,verbose=1)
# Out:
# Epoch 1/20
# 27/27 [==============================] - 3s 27ms/step - loss: 0.0000e+00 - accuracy: 0.3575 - val_loss: 0.0000e+00 - val_accuracy: 0.3290
# Epoch 2/20
# 27/27 [==============================] - 0s 18ms/step - loss: 0.0000e+00 - accuracy: 0.3575 - val_loss: 0.0000e+00 - val_accuracy: 0.3290
# Epoch 3/20
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.3575 - val_loss: 0.0000e+00 - val_accuracy: 0.3290
# Epoch 4/20
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.3575 - val_loss: 0.0000e+00 - val_accuracy: 0.3290
# Epoch 5/20
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.3575 - val_loss: 0.0000e+00 - val_accuracy: 0.3290
# Epoch 6/20
# 27/27 [==============================] - 0s 16ms/step - loss: 0.0000e+00 - accuracy: 0.3575 - val_loss: 0.0000e+00 - val_accuracy: 0.3290
# Epoch 7/20
# ...

# %%
prediction=model.predict(x_test)
# Out:
# 8/8 [==============================] - 0s 3ms/step

# %%
acc4 = accuracy_score(prediction,y_test)
acc4=acc4*100
acc4
# Out:
# 32.900432900432904

# %%
from sklearn.svm import SVC
svc=SVC()
svc.fit(x_train,y_train)
y_pred=svc.predict(x_test)
acc5=accuracy_score(y_pred,y_test)
acc5=acc5*100
acc5
# Out:
# 77.05627705627705

# %%
# save the model to disk
import pickle
filename = 'SVC.sav'
pickle.dump(svc, open(filename, 'wb'))

# %%
loaded_model = pickle.load(open(filename, 'rb'))

# %%
from sklearn.ensemble import StackingClassifier
from sklearn.naive_bayes import GaussianNB
hybrid = list()
hybrid.append(('RF', RandomForestClassifier()))
hybrid.append(('LR', LogisticRegression()))
model_h=StackingClassifier(estimators=hybrid)
model_h.fit(x_train, y_train)
y = model_h.predict(x_test)
acc6 = accuracy_score(y_test, y)
acc6=acc6*100
acc6
# Out:
# C:\Users\ymts0611\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# C:\Users\ymts0611\AppData\Roaming\Python\Python310\site-packages\sklearn\linear_model\_logistic.py:444: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
data={'models':['dtc','forest','lr','ann','svc','hybrid'],'values':[acc1,acc2,acc3,acc4,acc5,acc6]}
df=pd.DataFrame(data)
df
# Out:
#    models     values
# 0     dtc  65.800866
# 1  forest  78.787879
# 2      lr  79.653680
# 3     ann  32.900433
# 4     svc  77.056277
# 5  hybrid  80.086580

# %%
#here showing the accuracy in barplots
data={'models':['dtc','forest','lr','ann','svc','hybrid'],'values':[acc1,acc2,acc3,acc4,acc5,acc6]}
ax=df.plot.bar(x='models',y='values')
